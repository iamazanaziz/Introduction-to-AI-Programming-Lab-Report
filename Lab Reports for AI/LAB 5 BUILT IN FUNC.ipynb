# %% [markdown]
# # FREQUENTLY USED METHODS

# %% [markdown]
# ## Lab Report Tasks:
# ## sum: sum() adds up numbers in a list.
#
# i.	The power consumed by individual components is listed in a list. Find the total power consumed by adding readings.
#
# ii.	A list contains the values of a series of connected resistances. Find its equivalent resistance using the sum.
#
# Example:
#
# nums = [1, 2, 3]
#
# print(sum(nums))
#
# Output:
#
# 6

# %%
power_readings = [10, 20, 15, 5]  # in watts
total_power = sum(power_readings)
print("Total Power Consumed:", total_power, "W")

resistances = [5, 10, 15]  # in ohms
total_resistance = sum(resistances)
print("Equivalent Series Resistance:", total_resistance, "Ω")

#EXAMPLE PROVIDED FOR ABOVE METHOD
nums = [1, 2, 3]
print("Sum of nums:", sum(nums))
# Out:
# Total Power Consumed: 50 W
# Equivalent Series Resistance: 30 Ω
# Sum of nums: 6

# %% [markdown]
# ---
