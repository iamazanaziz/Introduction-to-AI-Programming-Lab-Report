# %% [markdown]
# # LAMBDA FUNCTION
# ## Lab Report Tasks:
# You are working in a university electronics lab.
# You are asked to monitor a small solar home system installed on the lab roof. The system has
#
# a)	A solar panel
# b)	A battery
# c)	A load controller
# d)	A temperature sensor

# %% [markdown]
# I.	Create a dictionary named reading1 containing the 5 fields shown in the scenario.
#
# II.	From reading1, print:
#
# i.	The solar power
#
# ii.	The battery voltage
#
# iii.	The load status
#
# III.	Print how many fields the dictionary contains after your modifications.
#
# IV.	Remove the "panel_current" field.
#
# V.	Get Keys, Values, and Items
#
# Print:
#
# i.	All keys
#
# ii.	All values
#
# iii. All key-value pairs
#
# iv.	Use .keys(), .values(), and .items().

# %%
reading1 = {
    "solar_power": 450,
    "panel_current": 8,
    "battery_voltage": 12.6,
    "load_status": "ON",
    "temperature": 35
}

print(reading1["solar_power"])
print(reading1["battery_voltage"])
print(reading1["load_status"])
# Out:
# 450
# 12.6
# ON

# %%
print(len(reading1))

reading1.pop("panel_current")

print(len(reading1))
# Out:
# 5
# 4

# %%
print(reading1.keys())
print(reading1.values())
print(reading1.items())
# Out:
# dict_keys(['solar_power', 'battery_voltage', 'load_status', 'temperature'])
# dict_values([450, 12.6, 'ON', 35])
# dict_items([('solar_power', 450), ('battery_voltage', 12.6), ('load_status', 'ON'), ('temperature', 35)])

# %% [markdown]
# ---
