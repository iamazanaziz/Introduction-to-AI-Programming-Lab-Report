# %% [markdown]
# # Lab Report Tasks:
# ## A resistor with zero value creates a short circuit, which can damage the circuit. Students need to test the resistance before use.
#
# Check if the resistance value is zero. If yes, print "Short Circuit", else print "Safe".
#
# Store resistance in a variable, use if-else.

# %%
resistance = int(input("Enter resistance value: "))          

if resistance == 0:           
    print("Short Circuit")
else:
    print("Safe")
# Out:
# Short Circuit

# %% [markdown]
# ---

# %% [markdown]
# ## EXTRA TASK
# An LED requires a minimum voltage to operate safely.
# If the supplied voltage is less than 3 volts, the LED will not turn on.
#
# Check the voltage value.
#
# If voltage is less than 3, print "LED Off"
#
# Otherwise, print "LED On"
#
# Store the voltage in a variable and use an if–else statement.

# %%
voltage = float(input("Enter voltage value: "))

# Check voltage condition
if voltage < 3:
    print("LED Off")
else:
    print("LED On")
# Out:
# LED On

# %% [markdown]
# ---
