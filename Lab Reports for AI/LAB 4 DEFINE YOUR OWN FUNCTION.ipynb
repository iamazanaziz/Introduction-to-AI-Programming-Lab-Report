# %% [markdown]
# # Define Your Own Function
# ## Lab Report Tasks:

# %% [markdown]
# ## In circuit design, you often calculate series resistance.
# •	Write a functionseries() that takes a list or tuple of resistances.
#
# •	Return the total resistance.
#
# •	Add docstrings and annotations.
#
# •	Print the function’s __annotations__.

# %%
def series(resistances: list) -> float:
    
    total = 0
    for r in resistances:
        total += r
    return total

resistors = [10, 50, 30]
total_resistance = series(resistors)
print("Total Series Resistance:", total_resistance, "Ω")
print("Function annotations:", series.__annotations__)
# Out:
# Total Series Resistance: 90 Ω
# Function annotations: {'resistances': <class 'list'>, 'return': <class 'float'>}

# %% [markdown]
# ---
